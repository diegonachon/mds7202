# %% [markdown]
# <h1><center>Laboratorio 2: OOP con Imágenes 📷</center></h1>
#
# <center><strong>MDS7202: Laboratorio de Programación Científica para Ciencia de Datos - otoño 2024</strong></center>

# %% [markdown]
# ### Cuerpo Docente:
#
# - Profesores: Ignacio Meza, Sebastián Tinoco
# - Auxiliar: Catherine Benavides
# - Ayudante: Nicolás Ojeda, Eduardo Moya

# %% [markdown]
# ### Equipo: SUPER IMPORTANTE - notebooks sin nombre no serán revisados
#
# - Nombre de alumno 1: Diego Cornejo

# %% [markdown]
# ### **Link de repositorio de GitHub:** `https://github.com/diegonachon/mds7202/tree/master/lab2`

# %% [markdown]
# ## Reglas:
#
# - **Grupos de 2 personas**
# - Fecha de entrega: 7 días desde la publicación, 3 días de atraso con 1 punto de descuento c/u.
# - Instrucciones del lab el viernes a las 16:15 en formato online. Asistencia no es obligatoria.
# - <u>Prohibidas las copias</u>. Cualquier intento de copia será debidamente penalizado con el reglamento de la escuela.
# - Tienen que subir el laboratorio a u-cursos Y a su repositorio de github. Labs que no estén en u-cursos no serán revisados. Recuerden que el repositorio también tiene nota.
# - Cualquier duda fuera del horario de clases al foro. Mensajes al equipo docente serán respondidos por este medio.
# - Pueden usar cualquer material del curso que estimen conveniente.

# %% [markdown]
# ### Temas a tratar:
#
# - Programación Orientada a Objetos.
# - Programación Funcional.
# - `Numpy` para manejo de datos en arreglos/tensores.

# %% [markdown]
# ### Objetivos principales del laboratorio
#
# - Aplicar los paradigmas y buenas prácticas de programación vistas hasta este momento.
# - Comprender y aprovechar las ventajas que nos ofrece la liberia `numpy` con respecto a trabajar en Python 'puro'.
# - Visualizar aplicaciones de filtros de imágenes sin el uso de librerías.
# - Verificar que el uso indiscriminado de `for` puede afectar en la eficiencia en al procesar datos masivos.
#
#
# El laboratorio deberá ser desarrollado **sin el uso indiscriminado de iteradores nativos de python (aka "for", "while")**. La idea es que aprendan a exprimir al máximo las funciones optimizadas que nos entrega `numpy`, las cuales vale mencionar, son bastante más eficientes que los iteradores nativos sobre arreglos.
#
# El lab estará basado en algunos conceptos básicos de procesamiento de imágenes, por lo que te iremos guiando, paso a paso por cada uno de los tópicos a desarrollar.

# %% [markdown]
# ## Descripción del laboratorio.

# %% [markdown]
# En Data Science son múltiples las aplicaciones que exigen el uso exhaustivo de listas de varias dimensiones. Estas entidad reciben formalmente el nombre de **arreglos o tensores**.
#
# Pensemos en que queremos almacenar objetos en un casillero común y corriente: podemos pensar que este puede ser representado por una matriz de dos dimensiones: alto y ancho. ¿Que sucederá si este casillero nos queda pequeño y queremos guardar más información del mismo tipo?: La solución es simple es agregar otro casillero. Esto puede ser pensado como el aumento de la dimensión de nuestro objeto, pasando a ser ahora (alto, ancho, id casillero). Esto no es otra cosa que un **tensor de 3 dimensiones**.
#
#
#
# ![lab2_1.png](attachment:lab2_1.png)

# %% [markdown]
# ### ¿Bueno y que tiene que ver todo esto con las imágenes?
#
# Una imagen es una representación visual de una matriz que contiene de números que describen intensidades de color (llamados píxeles). Esto visto desde la perspectiva de una imagen en blanco y negro, vendria siendo una matriz que reune las diferentes intensidades de los pixeles desde 0 a 255.
#
# <br>
# <center>
# <img src="https://miro.medium.com/max/1386/1*bV7S0zACdidh11ikjYpLpQ.png" width=500 height=500 alt="Representación de una imagen" />
# </center>
# <br>

# %% [markdown]
# Cuando las imágenes poseen colores, las imágenes vendrían siendo "sin querer queriendo", una bella representación de lo que es un tensor: estas pueden ser representadas por un tensor de 3 dimensiones que les dan el *ancho, alto y el canal*, en donde son alojados los colores de la imagen.
#
# <br>
# <center>
# <img src="https://miro.medium.com/max/2146/1*icINeO4H7UKe3NlU1fXqlA.jpeg" width=300 height=300 alt="Representación de una imagen" />
# </center>
# <br>
#
# Como pueden ver, la imagen puede ser interpretada como un tensor de tres dimensiones(un ancho, un alto y la intensidad de cada color) en el a cada posición $(i,j)$ de la imagen, le asociaremos 3 intensidades de colores RGB (Rojo, Verde y Azul). Estas intensidades irán desde el $0$ al $255$. La combinación de estos 3 canales nos permitirá representar gran parte de los colores que encontramos en la naturaleza.

# %% [markdown]
# **Instalar paquetes: Si están usando conda**

# %%
# import sys

# !conda install --yes --prefix {sys.prefix} pillow plotly imageio

# %% [markdown]
# **Instalar paquetes: Si están usando pip**

# %%
# !pip install pillow plotly imageio
# Out:
# Requirement already satisfied: pillow in /opt/conda/lib/python3.8/site-packages (8.1.2)
# Requirement already satisfied: plotly in /opt/conda/lib/python3.8/site-packages (5.20.0)
# Requirement already satisfied: imageio in /opt/conda/lib/python3.8/site-packages (2.9.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.8/site-packages (from imageio) (1.24.4)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.8/site-packages (from plotly) (20.9)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/conda/lib/python3.8/site-packages (from plotly) (8.2.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/lib/python3.8/site-packages (from packaging->plotly) (2.4.7)

# %% [markdown]
# **En caso de trabajar con colab:**

# %%
try:
    from google.colab import drive

    drive.mount("/content/drive")
    path = "/content/drive/My Drive/CuerpoDocente/Laboratorios/Lab1-Numpy/"
except:
    print('Ignorando conexión drive-colab')
# Out:
# Ignorando conexión drive-colab

# %%
# En este lab usaremos adicionalmente pillow, una estupenda librería
# para manejar imágenes.
# https://pillow.readthedocs.io/en/stable/

from PIL import Image
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt

foto = np.array(Image.open("./images_lab/cobija.PNG").convert("RGB"))

# Solo para ejemplificar, usaremos plotly (NO USARLO EN LO QUE QUEDA DEL LAB).
# Pero en el restro del laboratorio, matplotlib debe ser usado

# Lo cambié, no me corría con px
# fig = px.imshow(foto)
# fig.show()

plt.imshow(foto)
plt.show()

# %% [markdown]
# Luego, llamando la variable donde alojamos el array podemos ver los valores que componen a esta imagen.

# %%
print(f'Número de dimensiones: {foto.ndim}')
print(f'Número de elementos por dimensión: {foto.shape}')
# Out:
# Número de dimensiones: 3
# Número de elementos por dimensión: (470, 597, 3)

# %% [markdown]
# Finalmente visualizamos de forma aleatoria los pixeles de cada canal para mostrar sus intensidades.

# %%
print(f"Ejemplo de pixel (10, 200) en el canal 0 - Red: {foto[10, 200, 0]}")
print(f"Ejemplo de pixel (10, 200) en el canal 1- Green: {foto[10, 200, 1]}")
print(f"Ejemplo de pixel (10, 200) en el canal 2- Blue: {foto[10, 200, 2]}")
# Out:
# Ejemplo de pixel (10, 200) en el canal 0 - Red: 97
# Ejemplo de pixel (10, 200) en el canal 1- Green: 70
# Ejemplo de pixel (10, 200) en el canal 2- Blue: 48

# %% [markdown]
# Con lo anterior, suponiendo que la imagen del "gatito" tiene una altura igual a 600 y un ancho de 400, el tensor $G$ que representa a la imagen vendrá dado por $G[600, 400, 3]$.
#
# ### Videos
#
# Luego, si queremos complejizar aún mas esto y queremos tener tensores que agrupen un conjunto de imágenes (de igual tamaño) tendremos lo siguiente:
#
#
# <br>
# <center>
# <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRk4BWrH_xi_blsx9Y32OTT8k80vI90udG-Yg&usqp=CAU" width=300 height=300 alt="Representación de una imagen" />
# </center>
# <br>
#
# Este conjunto de imágenes nos generará la necesidad de producir una nueva dimensión, esto producto que las dimensiones son los espacios donde alojamos la información, por esto al conjunto de imágenes le agregaremos una dimensión que identifica cada una de las imágenes del conjunto, quedando representada por el tensor $G[0:n_d, 600, 400, 3]$. Por lo general, cuando tenemos imágenes con dimensionalidad 4 es porque se tratan de videos, o sea una secuencia de imágenes; el caso se complejiza aún más cuando agregamos sonido y esto se va a las pailas.
#
# <blockquote>Dato:
# La representación que posee cada una de las dimensiones puede cambiar dependiendo de la librería utilizada, en pytorch por ejemplo las dimensiones de una imagen vienen dadas por [batch, canales, alto, ancho] y no [batch, alto, ancho, canales] como en numpy.
# </blockquote>

# %% [markdown]
# ### ¿Ya, pero esto tiene aplicaciones más allá de guardar información en casilleros?
#
# Para el caso de imágenes podemos encontrar múltiples aplicaciones con la manipulación de los tensores y operando matemáticamente con ellos. Algunas de las aplicaciones más conocidas (y que aplicaremos) son las siguientes:
#
# - **Obtener el negativo de una imagen**: Consiste en obtener el color complementario de una imagen, para esto debemos restar la imagen con la máxima intensidad que podemos encontrar en una imagen (o sea 255).
#
#
# - **Pasar a escala de grises una imagen**: Los valores RGB se convierten a escala de grises mediante la fórmula NTSC:
#
#     $$ imagen\_gris = 0.299 * Rojo + 0.587 * Verde + 0.114 * Azul $$
#
#     Esta fórmula representa la percepción relativa de la persona promedio del brillo de la luz roja, verde y azul.
#
#
# - **Mejora de contraste**: Son múltiples las técnicas que nos permiten mejorar el contraste de una imagen, pero, una técnica simple para modificar los contrastes consta en obtener un factor de corrección llamado F en base al contraste deseado (C). Luego, es aplicado en la diferencia entre la imagen y 128. De esta forma obtenemos R, que es la imagen con la mejora de contraste deseada.
#
#     $$ F=259*(C+255)/(255*(259-C)) $$
#     $$ R=F*(img-128)+128 $$
#
#
# - **Convolución**: Consiste en recorrer una imagen por cada uno de sus canales utilizando una matriz que lleva por nombre Kernel. El kernel, examinará los conjuntos de pixeles que recorre, aplicando una multiplicación de los valores circundantes ,y sumando todos los valores generados de este producto para generar un nuevo pixel en el tensor de salida.
#
# ![conv](https://media3.giphy.com/media/i4NjAwytgIRDW/giphy.gif "miracomorecorre")

# %% [markdown]
# ---
#
# # Desarrollo

# %% [markdown]
# En base a lo explicado y visto en clases, a continuación, deben construir cada uno de los programas solicitados en las actividades señaladas más abajo. Estás, deben ser desarrollados de forma grupal (**2 personas por grupo**) y, la solución no debe ser compartida con personas externas al grupo; si se detecta que dos grupos entregan el mismo trabajo, será considerado plagio y se tomaran medidas al respecto.

# %% [markdown]
# ## 2. Creación de Clases y Funciones.

# %% [markdown]
# #### Importamos librerias utiles 😸

# %%
# !pip install scipy
# Out:
# Requirement already satisfied: scipy in /opt/conda/lib/python3.8/site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.16.5 in /opt/conda/lib/python3.8/site-packages (from scipy) (1.24.4)

# %%
# Libreria Core del lab.
import numpy as np
from pathlib import Path

# Librerias para graficar
import matplotlib.pyplot as plt

# Nota: Utilizar solo matplot para este lab. NO USAR PLOTLY,
# ya que tiene problemas de compatibilidad con imagenes

# Funcionalidades dependientes del Sistema Operativo.
import os

# Librerias utiles para cargar y generar Gifs
import imageio
from PIL import Image
from scipy.signal import convolve2d

# %% [markdown]
# ### 2.1. Carga de imagenes y visualización

# %% [markdown]
# Descomprima el archivo "images_lab.zip" en algún directorio de su computador o plataforma, observen las imágenes y clasifíquenlas a su gusto, para luego en un diccionario cargar y agrupar las diferentes imágenes (no cree mas de tres llaves).
#
# Hecho esto, visualize dos imágenes y verifique la dimensionalidad de estas imágenes con el comando *.shape*. Comente la dimensionalidad de las imágenes.

# %% [markdown]
# ### Carga de imagenes en diccionarios
#
# Las siguientes celdas de código le permitirá cargar las imágenes que utilizaremos durante este laboratorio.
#
# La primera celda implementa la función `from_jpg`, la cual, dado una ruta, carga una imágen:

# %%
def from_jpg(path):
    ruta = Path(path)
    image = np.array(Image.open(ruta), dtype='int')
    return image

# %% [markdown]
# La segunda celda carga las imágenes y las guarda en un diccionario.

# %%
images = {
    "gatitos": [
        from_jpg("./images_lab/gato1.jpg"),
        from_jpg("./images_lab/gato2.jpg"),
        from_jpg("./images_lab/gato4.jpg"),
    ],
    "Personas": [
        from_jpg("./images_lab/personas.jpg"),
        from_jpg("./images_lab/gurus.jpg"),
    ],
    "Monos_chinos": [from_jpg("./images_lab/monitos.jpg")],
}

# %% [markdown]
# ### Plot de imagenes
# A continuación, utilice la función `def show(imagen)` (definida más abajo) para explorar las imágenes cargadas en la celda anterior.
#
# **Respuesta Esperada**:

# %%
def show(imagen):
    plt.imshow(imagen)
    plt.show()
    x, y, z = imagen.shape
    print(f'Dimensiones de la imagen: {x}x{y} (Alto x Ancho)')

# %%
show(images['gatitos'][0])
# usar show para mostrar las otras imágenes...
# Out:
# Dimensiones de la imagen: 869x750 (Alto x Ancho)

# %% [markdown]
# ### **Respuestas**

# %% [markdown]
# **Diccionario**

# %%
images = {
    "gatos": [
        from_jpg("./images_lab/cobija.PNG"),
        from_jpg("./images_lab/gato1.jpg"),
        from_jpg("./images_lab/gato2.jpg"),
        from_jpg("./images_lab/gato4.jpg"),
    ],
    "no_gatos": [
        from_jpg("./images_lab/gurus.jpg"),
        from_jpg("./images_lab/monitos.jpg"),
        from_jpg("./images_lab/personas.jpg"),
    ],
}

# %% [markdown]
# **Mostrar 2 imagenes y su dimensionalidad**

# %%
foto1 = np.array(Image.open("./images_lab/gato1.jpg").convert("RGB"))

plt.imshow(foto1)
plt.show()
print('Dimensionalidad: ', foto1.shape)
# Out:
# Dimensionalidad:  (869, 750, 3)

# %%
foto1 = np.array(Image.open("./images_lab/gato2.jpg").convert("RGB"))

plt.imshow(foto1)
plt.show()
print('Dimensionalidad: ', foto1.shape)
# Out:
# Dimensionalidad:  (933, 700, 3)

# %% [markdown]
# **Usar show para mostrar las otras imagenes**

# %%
import pandas as pd
serie_images = pd.Series(images)
serie_images.apply(lambda x: list(map(show, x)))
# Out:
# Dimensiones de la imagen: 869x750 (Alto x Ancho)
# Dimensiones de la imagen: 933x700 (Alto x Ancho)
# Dimensiones de la imagen: 1200x1600 (Alto x Ancho)
# Dimensiones de la imagen: 630x1200 (Alto x Ancho)
# Dimensiones de la imagen: 380x506 (Alto x Ancho)
# Dimensiones de la imagen: 1079x1917 (Alto x Ancho)
# gatitos         [None, None, None]
# Personas              [None, None]
# Monos_chinos                [None]
# dtype: object

# %% [markdown]
# ### 2.2 Clase imagenes [2 puntos].

# %% [markdown]
# Ahora que sabemos cómo plotear y cargar una imagen, cree una clase llamada "Imagen" la que cumpla las siguientes características:
#
# - [X] Un constructor que tome como argumento una imagen y que lo guarde como un atributo. `__init__` debe comprobar que la imagen es un arreglo de numpy (con `isinstance`) y adicionalmente que este tiene 3 dimensiones. En caso contrario, debe levantar excepciones con mensajes correspondientes al error detectado (ustedes definen el mensaje).
# - [X] Implemente el método `show()` que muestre la imagen usando la función `plt.show()`.
# - [X] Implemente el método `info()` que retorna un string con las dimensiones de la imagen.
# - [X] Sobrecargue el método mágico `__mul__`, `__add__` y `__sub__` para realizar operaciones matemáticas entre el objeto y arrays, int o floats. Realice la función pensando que la operación se puede aplicar tanto para izquierda y derecha. Como estamos trabajando con imágenes los outputs deben ser enteros, por esto se le aconseja utilizar `.astype(int)` para transformar los arrays de salida a un formato legible por matplotlib.
# - [X] Es importante que para las operaciones `__add__` y `__sub__` implementen una saturación de las imágenes. Es decir, la suma o resta deben dar como valor máximo 255 y/o como valor mínimos mayores o iguales a 0.
# - [X] Para el caso de `__mul__` deben implementar un método que nos permita saturar las imágenes (es decir que los valores del array no sobrepasen 255) y también no nos permita obtener valores inferiores a cero.
#
# Implementadas los métodos, compruebe que la funcionalidad es la correcta mediante la ejecución de los asserts incluidos un par de celdas más abajo.
#
# > **Notas:**
# - Pueden reutilizar el código implementado en las celdas anteriores para implementar los métodos `show` e `info` . Sin embargo, No invoquen directamente esas funciones.
# - La idea es que la imagen contenida en la clase sea inmutable, por ende, todos los metodos que modifiquen la imagen contenida en el objeto deberan retornar un nuevo objeto de la clase `Imagen` que contenga la imagen modificada.

# %%
class Imagen:
    """Clase contenedora de imágenes"""

    def __init__(self, img):
        if isinstance(img, np.ndarray):
            if img.ndim != 3:
                raise ("El argumento debe ser un arreglo de numpy de solo 3 dimensiones")
            if img.shape[-1] != 3:
                raise (
                    "El argumento debe ser un arreglo de numpy de solo 3 dimensiones "
                    "tal que la última dimensión solo tiene 3 canales"
                )
            self.imagen = img
        else:
            raise TypeError(
                "Debes entregar un arreglo de numpy como argumento del constructor de "
                "Imagen"
            )

    def show(self):
        """Muestra la imágen contenida en el objeto.
        Su funcionalidad debe ser igual a la de la función mostrar_imagen.
        """        
        plt.imshow(self.imagen)
        plt.show()


    def info(self):
        """ Imprime las características de la imagen cargada: Alto y ancho.
        """
        x, y, z = self.imagen.shape
        print('Caracteristicas de la imagen cargada:')
        print('Alto: ', x)
        print('Ancho: ', y)
        

    def __add__(self, other):
        """Redefine la operación + entre imagen y escalar.

        # Idea, usar indexado condicial (similar a los filtros de pandas).
        # Sumar y luego que en cada pixel mayor a 255 sea asignado el máximo.
        # Ver los tests para mas información.

        Parameters
        ----------
        other : Union[int, float, np.ndarray]
            Escalar o arreglo que será sumado a cada pixel de la imagen
        """
        add_imagen = Imagen(np.clip(self.imagen + other, 0, 255).astype(int))
        return add_imagen
    

    def __radd__(self, other):
        """Operación conmutativa de __add__.

        Hint: debería llamar a __add__...

        Parameters
        ----------
        other : Union[int, float, np.ndarray]
            Escalar o arreglo que será sumado a cada pixel de la imagen
        """
        radd_imagen = self.__add__(other)
        return radd_imagen
    

    def __sub__(self, other):
        """Redefine la operación + entre imagen y escalar.

        # Idea, usar indexado condicial (similar a los filtros de pandas).
        # Restar y luego que en cada pixel mayor a 255 sea asignado el máximo.
        # Caso similar para valores menores a 0, donde debera asignar el minimo a esos pixeles
        # Ver los tests para mas información.

        Parameters
        ----------
        other : Union[int, float, np.ndarray]
            Escalar o arreglo que será sumado a cada pixel de la imagen
        """
        sub_imagen = Imagen(np.clip(self.imagen - other, 0, 255).astype(int))
        return sub_imagen
        

    def __rsub__(self, other):
        """Operación conmutativa de __sub__.

        Parameters
        ----------
        other : Union[int, float, np.ndarray]
            Escalar o arreglo que será sumado a cada pixel de la imagen
        """
        rsub_imagen = Imagen(np.clip(other - self.imagen, 0, 255).astype(int))
        return rsub_imagen
    

    def __mul__(self, other):
        """Redefine la operación + entre imagen y escalar.

        # Idea, usar indexado condicial (similar a los filtros de pandas).
        # Sumar y luego que en cada pixel mayor a 255 sea asignado el máximo y
        # cada valor inferior a 0 debe ser 0.
        # Ver los tests para mas información.

        Parameters
        ----------
        other : Union[int, float, np.ndarray]
            Escalar o arreglo que será sumado a cada pixel de la imagen
        """
        mul_image = Imagen(np.clip(self.imagen * other, 0, 255).astype(int))
        return mul_image
        

    def __rmul__(self, other):
        """Operación conmutativa de __mul__.

        Hint: debería llamar a __mul__...

        Parameters
        ----------
        other : Union[int, float, np.ndarray]
            Escalar o arreglo que será sumado a cada pixel de la imagen
        """
        rmul_image = self.__mul__(other)
        return rmul_image

# %% [markdown]
# **Resultados esperados:**

# %%
gatito = Imagen(images["gatitos"][1])
gurus = Imagen(images["Personas"][1])

# %%
# Test show e info.
gatito.show()
gatito.info()

gurus.show()
gurus.info()
# Out:
# Caracteristicas de la imagen cargada:
# Alto:  933
# Ancho:  700
# Caracteristicas de la imagen cargada:
# Alto:  380
# Ancho:  506

# %%
# Tests de los overload de operadores.

# Test __add__
# Idea del test: Todos los elementos de la imagen deben ser a lo más 255.

# Test __add__
assert np.max((gatito + 1000).imagen) == 255

# Test __radd__
assert np.max((1000 + gatito).imagen) == 255

# Test __sub__
assert np.min((gatito - (-1000)).imagen) == 255

# Test __sub__
assert np.max((gatito - 1000).imagen) == 0

# Test __rsub__
assert np.min((1000 - gatito ).imagen) == 255

# Test __mul__ (probar minimo)
assert np.max((-555555 * gatito).imagen) == 0

# Test __mul__ (probar maximo)
assert np.max((555555*gatito).imagen) == 255

# Test __rmul__ (probar minimo)
assert np.max((gatito*-555555).imagen) == 0

# Test __rmul__ (probar maximo)
assert np.max((gatito*555555).imagen) == 255

# %% [markdown]
# ### 2.3 Clase de Procesamiento de Imagenes [2 puntos]

# %% [markdown]
# Ahora que comprenden las diferentes dimensiones que componen a una imagen (en la práctica), ahora realizaremos diferentes tareas de procesamiento de imágenes. Para esto, deben crear una clase llamada "`LibImagen`" que cumpla los siguientes requisitos:
#
# - [X] Pasar una imagen a escala de grises, para esto utilice la ecuación (1) expuesta en este mismo notebook.
# - [X] Obtener los canales R, G y B de forma individual.
# - [X] Crear una función que pase a negativo de la imagen alojada.
# - [X] Mejorar el contraste de una imagen.
# - [X] Realizar una convolución sobre la imagen.
# - [X] Documentar la clase creada y verificar la documentación con el comando help().

# %% [markdown]
# > **Nota 🗒️**: Todo método debe tomar una Imagen y retornar una nueva Imagen.
#
# > **Nota 2**: El tipo de datos del arreglo de la imagen que generen o modifiquen debe ser "int". De lo contrario, puede no visualizarse correctamente.

# %%
class LibImagen():

    def to_negative(self, img_in):
        """Convierte imagen a negativo.

        Parameters
        ----------
        img_in : Imagen
            Objeto Imagen que contiene imagen a procesar.

        Returns
        -------
        Imagen
            Objeto Imagen con la imagen procesada.
        """
        neg_image = 255 - img_in.imagen
        return Imagen(neg_image)
        
        
    def to_gray(self, img_in):
        """
        Transforma una imagen en RGB a la escala de grises.

        Parameters
        ----------
        img_in : Imagen
            Objeto Imagen que contiene una imagen.

        Returns
        -------
        Imagen
            Una que contiene una imagen con 3 canales.
            Los 3 canales deben tener los mismos valores.
        """
        weights = [0.299, 0.587, 0.114]
        
        gray_image = np.dot(img_in.imagen[...,:3], weights)
        gray_image = np.stack((gray_image, gray_image, gray_image), axis=-1).astype(int)
        return Imagen(gray_image)
    
        

    def get_channel(self, img_in, channel):
        """Obtiene un canal de un color seteando el resto de los canales en 0.

        Parameters
        ----------
        img_in : Imagen
            Objeto Imagen que contiene una imagen.
        channel : str
            Nombre del canal que será seleccionado. Valores posibles: ('r','g' o 'b').

        Returns
        -------
        Imagen:
            Objeto Imagen que contiene una imagen con 3 canales.
            Solo el canal seleccionado debe tener valores distintos a 0.
        """
        if channel == 'r':
            channel_index = 0
        if channel == 'g':
            channel_index = 1
        if channel == 'b':
            channel_index = 2

        channel_image = np.zeros_like(img_in.imagen)
        channel_image[:, :, channel_index] = img_in.imagen[:, :, channel_index]
        return Imagen(channel_image)
        

    def set_contrast(self, img_in, C):
        """Mejora el contraste de una imagen.

        Parameters
        ----------
        img_in : Imagen
            Objeto Imagen que contiene una imagen.
        C : float
            Parámetro que define el ajuste de contraste.

        Returns
        -------
        Imagen
            Objeto Imagen que contiene una imagen con 3 canales modificados.
        """ 
        F = 259 * (C + 255) / (255 * (259 - C))
        contrast_image = F * (img_in.imagen - 128) + 128
        contrast_image = np.clip(contrast_image, 0, 255)
        return Imagen(contrast_image.astype(int))
        

    def conv_channel(self, img_in, kernel):
        """Convoluciona cada canal de color de una imagen con un kernel dado.

        Parameters
        ----------
        img_in : Imagen
            Objeto Imagen que contiene la imagen de entrada.
        kernel : array
            Kernel de convolución que se aplicará a cada canal de color.

        Returns
        -------
        Imagen
            Objeto Imagen que contiene la imagen resultante después de aplicar la convolución.    
        """
        img = img_in.imagen
        img_out = []
        for i in range(img.shape[-1]):
            img_channel = convolve2d(img[:, :, i],
                                     kernel,
                                     mode="same",
                                     boundary="symm")
            img_out.append(img_channel)
        new_image = np.stack(img_out, axis=2)
        new_image[new_image>255], new_image[new_image<0] = 255, 0
        return Imagen(new_image.astype(int))

# %% [markdown]
# **Respuesta**

# %%
help(LibImagen)
# Out:
# Help on class LibImagen in module __main__:
#
# class LibImagen(builtins.object)
#  |  Methods defined here:
#  |
#  |  conv_channel(self, img_in, kernel)
#  |      Convoluciona cada canal de color de una imagen con un kernel dado.
#  |
#  |      Parameters
#  |      ----------
#  |      img_in : Imagen
#  |          Objeto Imagen que contiene la imagen de entrada.
#  |      kernel : array
#  |          Kernel de convolución que se aplicará a cada canal de color.
#  |
#  |      Returns
#  |      -------
#  |      Imagen
#  |          Objeto Imagen que contiene la imagen resultante después de aplicar la convolución.
#  |
#  |  get_channel(self, img_in, channel)
#  |      Obtiene un canal de un color seteando el resto de los canales en 0.
#  |
#  |      Parameters
#  |      ----------
#  |      img_in : Imagen
#  |          Objeto Imagen que contiene una imagen.
#  |      channel : str
#  |          Nombre del canal que será seleccionado. Valores posibles: ('r','g' o 'b').
#  |
#  |      Returns
#  |      -------
#  |      Imagen:
#  |          Objeto Imagen que contiene una imagen con 3 canales.
#  |          Solo el canal seleccionado debe tener valores distintos a 0.
#  |
#  |  set_contrast(self, img_in, C)
#  |      Mejora el contraste de una imagen.
#  |
#  |      Parameters
#  |      ----------
#  |      img_in : Imagen
#  |          Objeto Imagen que contiene una imagen.
#  |      C : float
#  |          Parámetro que define el ajuste de contraste.
#  |
#  |      Returns
#  |      -------
#  |      Imagen
#  |          Objeto Imagen que contiene una imagen con 3 canales modificados.
#  |
#  |  to_gray(self, img_in)
#  |      Transforma una imagen en RGB a la escala de grises.
#  |
#  |      Parameters
#  |      ----------
#  |      img_in : Imagen
#  |          Objeto Imagen que contiene una imagen.
#  |
#  |      Returns
#  |      -------
#  |      Imagen
#  |          Una que contiene una imagen con 3 canales.
#  |          Los 3 canales deben tener los mismos valores.
#  |
#  |  to_negative(self, img_in)
#  |      Convierte imagen a negativo.
#  |
#  |      Parameters
#  |      ----------
#  |      img_in : Imagen
#  |          Objeto Imagen que contiene imagen a procesar.
#  |
#  |      Returns
#  |      -------
#  |      Imagen
#  |          Objeto Imagen con la imagen procesada.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %% [markdown]
# ### 2.4 Probar [0,5 puntos]

# %% [markdown]
# **Respuesta Esperada**:

# %%
gatito = Imagen(images["gatitos"][1])

gatito.show()

lib = LibImagen()

print('Negativo')
lib.to_negative(gatito).show()

print('Grayscale')
lib.to_gray(gatito).show()

print('Selección de Canales')
lib.get_channel(gatito, "r").show()
lib.get_channel(gatito, "g").show()
lib.get_channel(gatito, "b").show()

print('Mejora de Contraste')
lib.set_contrast(gatito, 0).show()

print('Convolución')
kernel = np.array([[-1, -1,  -1],
                   [-1,  8,  -1],
                   [-1, -1,  -1]])

lib.conv_channel(gatito, kernel).show()
# Out:
# Negativo
# Grayscale
# Selección de Canales
# Mejora de Contraste
# Convolución

# %% [markdown]
# #### Implementar 5 Kernels y probarlos con las imagenes
#
# Referencia:
# https://en.wikipedia.org/wiki/Kernel_(image_processing)

# %%
# Convolución
kernel_1 = np.array([[0 , -1,  0],
                     [-1,  5, -1],
                     [0,  -1,  0]])


kernel_2 = (1/16) * np.array([[1 , 2 , 1],
                              [2 , 4 , 2],
                              [1 , 2 , 1]])


kernel_3 = np.array([[1  ,  2 ,  1],
                     [0  ,  0 ,  0],
                     [-1 , -2 , -1]])

kernel_4 = np.array([[-2  ,  -1 ,  0],
                     [-1  ,   1 ,  1],
                     [0   ,   1 ,  2]])

kernel_5 = np.array([[0 , 0 , 0],
                     [0 , 1 , 0],
                     [0 , 0 , 0]])

lib.conv_channel(gatito, kernel_1).show()
lib.conv_channel(gatito, kernel_2).show()
lib.conv_channel(gatito, kernel_3).show()
lib.conv_channel(gatito, kernel_4).show()
lib.conv_channel(gatito, kernel_5).show()

# %% [markdown]
# **Comente:**
#
# Para finalizar, comente que hace (o debería hacer) cada filtro convolucional al aplicarlas a su imagen de ejemplo.
#
#
# **Respuesta**
#
# ```
# 1.- Sharpen: Enfatiza la diferencia de los pixeles adjacentes dentro de la imagen, haciendo que se vea más vívida.
#
# 2.- Gaussian blur: Hace que los cada de la imagen sea un promedio ponderado de los pixeles en su vecindario, generando una imagen suavizada sin detalles finos.
#
# 3.- Top sobel: El kernel "sobel" muestra las diferencias entre pixeles adjacentes en una dirección en particular (en es caso, hacia arriba).
#
# 4.- Emboss: Similar al "sobel", muestra las diferencias entre pixeles adjacentes en una dirección en particular (en este caso, desde arriba a la izquierda hacia abajo a la derecha), y enfatiza estas.
#
# 5.- Identidad: No se hacen cambios en la imagen, cada pixel se mantiene igual.
# ```

# %% [markdown]
# ## 3. Secuencias y Detección de Movimiento

# %% [markdown]
# ### 3.2. Secuencia de Imagenes [1,5 punto]

# %% [markdown]
# A continuación, deben programar una función que nos permite resaltar los objetos en movimientos de una secuencia de imágenes. Para esta parte del laboratorio, deberá utilizar las imágenes dispuestas en la carpeta `secuencia_plaza` del archivo zip subido a material docente.

# %% [markdown]
# Primero que todo, cargue la secuencia de imágenes que se encuentran en el directorio. Para esto, se recomienda utilizar el comando `os.listdir(dir)`, ya que este le facilitará la carga de un gran número de imágenes (pruebe el comando y vea que sucede).

# %%
path = "./secuencia_plaza/"
img_names = os.listdir(path)
#se agrega un sort para tener las imagenes ordenadas
img_names.sort()


imagenes = np.array(list(map(lambda img: np.array(Image.open(path + img)), img_names)))

# %% [markdown]
# ![plaza se mueve](https://media0.giphy.com/media/ZAzlopoHETs5lZQ6EZ/giphy.gif "plaza")

# %% [markdown]
# Para realizar este ejercicio utilizaremos un método super básico para la eliminación de fondo. Para esto sigue la siguiente receta:
#  1. Pase a escala de grises todas las imágenes secuenciales.
#  2. Almacene en una variable la resta de las imágenes consecutivas.

# %% [markdown]
#    $$ imagen\_out = imagen(t) - imagen(t+1) $$

# %% [markdown]
#  3. Establezca un umbral para eliminar algunos artefactos. Pruebe con al menos 3 umbrales.

# %% [markdown]
# $$ imagen\_out = imagen\_out> Umbral $$

# %% [markdown]
# **Nota**: No es necesario que construya una clase para esta parte.

# %%
def dect_mov(sec_img, umbral=30):
    arreglo_gris = np.dot(sec_img[..., :3], [0.299, 0.587, 0.114])
    resta = arreglo_gris[:-1] - arreglo_gris[1:]
    resultado_umbral = np.where(resta > umbral, resta, 0)
    return resultado_umbral

# %% [markdown]
# ### 3.3 Resultado

# %% [markdown]
# Ahora es tiempo de relajarse y ver si nuestro experimento logra resaltar los objetos en movimiento de esta polémica Plaza, para esto solo ejecute el siguiente Código y espere.

# %%
imageio.mimsave('plaza_10.gif', dect_mov(imagenes, 10))
# Out:
# Lossy conversion from float64 to uint8. Range [0.0, 251.07299999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 241.468]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.29]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 245.38299999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 252.81699999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.105]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.045]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 241.07299999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 242.638]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.50099999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.486]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.45299999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 244.97]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.774]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.333]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 251.37599999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.724]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 251.92899999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 244.35999999999999]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.942]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 245.1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.49099999999999]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.451]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 245.687]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 60.228]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 251.484]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 251.88099999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.739]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 252.13099999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 252.017]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 252.74599999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.71999999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.72699999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.48499999999999]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.27499999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.98]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 251.789]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 251.94599999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 252.20799999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 254.54399999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.887]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.01999999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.07]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.85999999999999]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.61499999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.68099999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 253.54399999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 252.41899999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.87699999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.118]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.331]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.62099999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.93499999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.77999999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.066]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.827]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 245.74099999999999]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.00099999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.42299999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.26799999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.16099999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 252.57199999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.22299999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.99099999999999]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.664]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.63099999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.48599999999996]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 244.958]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 245.926]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.186]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 237.77899999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.653]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.861]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 245.98999999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.87699999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 252.64699999999996]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.001]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.28799999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.334]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.57399999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 243.92399999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 251.56299999999996]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 252.10299999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.041]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.28799999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.68699999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.492]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.12199999999999]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 252.72899999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 252.35899999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 245.40299999999996]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.90299999999996]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 244.582]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 241.66299999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 240.397]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.42899999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.29399999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 252.989]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 245.89299999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.10999999999999]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.22299999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 252.41899999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 251.56099999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.28799999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.295]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 251.518]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.28799999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.14800000000002]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.724]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.87699999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.46899999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 252.24699999999999]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.77999999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 252.03799999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 251.28399999999996]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.099]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 242.956]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 245.92399999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.636]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.87]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 240.355]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.063]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 245.41899999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.905]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.135]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 243.947]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.109]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.94199999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.414]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.32599999999996]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 251.98]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.93599999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.29499999999996]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.20199999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.987]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 251.331]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.588]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 253.63199999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.658]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.99399999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 242.772]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 241.313]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.103]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.018]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.40399999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.533]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 245.674]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.63199999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.755]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 251.18699999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 253.011]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.593]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 243.696]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.718]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 251.83199999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.39299999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.984]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.31099999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.664]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.892]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.565]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.397]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 245.81]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.941]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.09799999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.22299999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.881]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.49999999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.914]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.393]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.59799999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 244.648]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.82099999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.11699999999996]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.25199999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.83799999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.39899999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.60999999999999]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.77999999999997]. Convert image to uint8 prior to saving to suppress this warning.

# %%
imageio.mimsave('plaza_30.gif', dect_mov(imagenes, 30))
# Out:
# Lossy conversion from float64 to uint8. Range [0.0, 251.07299999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 241.468]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.29]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 245.38299999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 252.81699999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.105]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.045]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 241.07299999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 242.638]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.50099999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.486]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.45299999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 244.97]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.774]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.333]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 251.37599999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.724]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 251.92899999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 244.35999999999999]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.942]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 245.1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.49099999999999]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.451]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 245.687]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 60.228]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 251.484]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 251.88099999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.739]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 252.13099999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 252.017]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 252.74599999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.71999999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.72699999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.48499999999999]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.27499999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.98]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 251.789]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 251.94599999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 252.20799999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 254.54399999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.887]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.01999999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.07]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.85999999999999]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.61499999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.68099999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 253.54399999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 252.41899999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.87699999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.118]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.331]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.62099999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.93499999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.77999999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.066]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.827]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 245.74099999999999]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.00099999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.42299999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.26799999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.16099999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 252.57199999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.22299999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.99099999999999]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.664]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.63099999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.48599999999996]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 244.958]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 245.926]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.186]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 237.77899999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.653]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.861]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 245.98999999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.87699999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 252.64699999999996]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.001]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.28799999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.334]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.57399999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 243.92399999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 251.56299999999996]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 252.10299999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.041]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.28799999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.68699999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.492]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.12199999999999]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 252.72899999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 252.35899999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 245.40299999999996]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.90299999999996]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 244.582]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 241.66299999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 240.397]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.42899999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.29399999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 252.989]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 245.89299999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.10999999999999]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.22299999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 252.41899999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 251.56099999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.28799999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.295]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 251.518]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.28799999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.14800000000002]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.724]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.87699999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.46899999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 252.24699999999999]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.77999999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 252.03799999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 251.28399999999996]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.099]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 242.956]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 245.92399999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.636]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.87]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 240.355]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.063]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 245.41899999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.905]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.135]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 243.947]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.109]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.94199999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.414]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.32599999999996]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 251.98]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.93599999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.29499999999996]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.20199999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.987]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 251.331]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.588]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 253.63199999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.658]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.99399999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 242.772]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 241.313]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.103]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.018]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.40399999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.533]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 245.674]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.63199999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.755]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 251.18699999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 253.011]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.593]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 243.696]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.718]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 251.83199999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.39299999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.984]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.31099999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.664]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.892]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.565]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.397]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 245.81]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.941]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.09799999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.22299999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.881]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.49999999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.914]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.393]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.59799999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 244.648]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.82099999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.11699999999996]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.25199999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.83799999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.39899999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.60999999999999]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.77999999999997]. Convert image to uint8 prior to saving to suppress this warning.

# %%
imageio.mimsave('plaza_50.gif', dect_mov(imagenes, 50))
# Out:
# Lossy conversion from float64 to uint8. Range [0.0, 251.07299999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 241.468]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.29]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 245.38299999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 252.81699999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.105]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.045]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 241.07299999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 242.638]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.50099999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.486]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.45299999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 244.97]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.774]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.333]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 251.37599999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.724]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 251.92899999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 244.35999999999999]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.942]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 245.1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.49099999999999]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.451]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 245.687]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 60.228]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 251.484]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 251.88099999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.739]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 252.13099999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 252.017]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 252.74599999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.71999999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.72699999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.48499999999999]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.27499999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.98]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 251.789]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 251.94599999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 252.20799999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 254.54399999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.887]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.01999999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.07]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.85999999999999]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.61499999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.68099999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 253.54399999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 252.41899999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.87699999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.118]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.331]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.62099999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.93499999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.77999999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.066]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.827]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 245.74099999999999]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.00099999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.42299999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.26799999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.16099999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 252.57199999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.22299999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.99099999999999]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.664]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.63099999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.48599999999996]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 244.958]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 245.926]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.186]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 237.77899999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.653]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.861]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 245.98999999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.87699999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 252.64699999999996]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.001]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.28799999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.334]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.57399999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 243.92399999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 251.56299999999996]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 252.10299999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.041]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.28799999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.68699999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.492]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.12199999999999]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 252.72899999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 252.35899999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 245.40299999999996]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.90299999999996]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 244.582]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 241.66299999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 240.397]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.42899999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.29399999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 252.989]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 245.89299999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.10999999999999]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.22299999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 252.41899999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 251.56099999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.28799999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.295]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 251.518]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.28799999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.14800000000002]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.724]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.87699999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.46899999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 252.24699999999999]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.77999999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 252.03799999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 251.28399999999996]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.099]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 242.956]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 245.92399999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.636]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.87]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 240.355]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.063]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 245.41899999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.905]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.135]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 243.947]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.109]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.94199999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.414]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.32599999999996]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 251.98]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.93599999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.29499999999996]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.20199999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.987]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 251.331]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.588]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 253.63199999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.658]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.99399999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 242.772]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 241.313]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.103]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.018]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.40399999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.533]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 245.674]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.63199999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.755]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 251.18699999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 253.011]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.593]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 243.696]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.718]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 251.83199999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.39299999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.984]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.31099999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.664]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.892]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.565]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.397]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 245.81]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.941]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.09799999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.22299999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.881]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.49999999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.914]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.393]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.59799999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 244.648]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.82099999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.11699999999996]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.25199999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.83799999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.39899999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.60999999999999]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.77999999999997]. Convert image to uint8 prior to saving to suppress this warning.

# %%
imageio.mimsave('plaza_80.gif', dect_mov(imagenes, 80))
# Out:
# Lossy conversion from float64 to uint8. Range [0.0, 251.07299999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 241.468]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.29]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 245.38299999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 252.81699999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.105]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.045]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 241.07299999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 242.638]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.50099999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.486]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.45299999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 244.97]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.774]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.333]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 251.37599999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.724]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 251.92899999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 244.35999999999999]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.942]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 245.1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.49099999999999]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.451]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 245.687]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 251.484]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 251.88099999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.739]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 252.13099999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 252.017]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 252.74599999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.71999999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.72699999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.48499999999999]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.27499999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.98]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 251.789]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 251.94599999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 252.20799999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 254.54399999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.887]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.01999999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.07]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.85999999999999]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.61499999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.68099999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 253.54399999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 252.41899999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.87699999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.118]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.331]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.62099999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.93499999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.77999999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.066]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.827]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 245.74099999999999]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.00099999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.42299999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.26799999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.16099999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 252.57199999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.22299999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.99099999999999]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.664]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.63099999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.48599999999996]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 244.958]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 245.926]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.186]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 237.77899999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.653]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.861]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 245.98999999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.87699999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 252.64699999999996]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.001]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.28799999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.334]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.57399999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 243.92399999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 251.56299999999996]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 252.10299999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.041]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.28799999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.68699999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.492]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.12199999999999]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 252.72899999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 252.35899999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 245.40299999999996]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.90299999999996]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 244.582]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 241.66299999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 240.397]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.42899999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.29399999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 252.989]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 245.89299999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.10999999999999]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.22299999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 252.41899999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 251.56099999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.28799999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.295]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 251.518]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.28799999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.14800000000002]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.724]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.87699999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.46899999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 252.24699999999999]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.77999999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 252.03799999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 251.28399999999996]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.099]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 242.956]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 245.92399999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.636]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.87]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 240.355]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.063]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 245.41899999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.905]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.135]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 243.947]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.109]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.94199999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.414]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.32599999999996]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 251.98]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.93599999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.29499999999996]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.20199999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.987]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 251.331]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.588]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 253.63199999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.658]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.99399999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 242.772]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 241.313]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.103]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.018]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.40399999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.533]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 245.674]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.63199999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.755]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 251.18699999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 253.011]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.593]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 243.696]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.718]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 251.83199999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.39299999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.984]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.31099999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.664]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.892]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.565]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.397]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 245.81]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.941]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 247.09799999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.22299999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.881]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.49999999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.914]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.393]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.59799999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 244.648]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.82099999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 248.11699999999996]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 246.25199999999998]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.83799999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.39899999999997]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.60999999999999]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.77999999999997]. Convert image to uint8 prior to saving to suppress this warning.

# %% [markdown]
# **Ejemplo de resultado esperado:**
#
# ![resultados](https://media3.giphy.com/media/SKV3bgUzHt0MLJTWW2/giphy.gif "res")

# %% [markdown]
# # Conclusión
# Eso ha sido todo para el lab de hoy, recuerden que el laboratorio tiene un plazo de entrega de una semana. Cualquier duda del laboratorio, no duden en contactarnos por mail o U-cursos.
#
# ![Gracias Totales!](https://media.giphy.com/media/5xtDaroSIXzLa6dvfI4/giphy.gif "cerati")

# %% [markdown]
# ### Referencias lab 1.
#
# - http://www.cs.cornell.edu/cv/SummerSchool/Introduction.pdf
# - https://en.wikipedia.org/wiki/Tensor
# - https://support.ptc.com/help/mathcad/es/index.html#page/PTC_Mathcad_Help/example_grayscale_and_color_in_images.html
# - http://w3.unpocodetodo.info/canvas/negativo.php
# - http://www.dfstudios.co.uk/articles/programming/image-programming-algorithms/image-processing-algorithms-part-5-contrast-adjustment/

# %% [markdown]
# <br>
# <center>
# <img src="https://i.kym-cdn.com/photos/images/original/001/194/195/b18.png" width=100 height=50 />
# </center>
# <br>
